# %% [markdown]
# <a href="https://colab.research.google.com/github/uswr1/My_First_Test_Repo/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа №2, вариант №7

# %%
from collections import Counter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('Current.csv')
#Второй пункт
print("Заголовок таблицы:")
print(data.columns)
print("Первые несколько строк:")
print(data.head())
print("Последние несколько строк:")
print(data.tail())

#Вариант №7
print('  ')
df =pd.read_csv('Current.csv')
first_1280_rows = df.head(1280)
mean_of_first_1280_rows = first_1280_rows.mean()
print('Среднее значение=', mean_of_first_1280_rows, 'микроампер')

P = (df.head(1280) **2) * 1e-10
plt.plot(P)
plt.show()
P_mean = P.mean()
print(' ')
print('среднее значение мощности из графика = ', P_mean, 'Ватт')
P_credn = (mean_of_first_1280_rows **2) * 1e-10
print('Среднее значение мощности теоретическое = ', P_credn, 'Ватт')

P_razn=P_mean-P_credn
P_razn_bool=bool(P_razn)
if P_razn_bool:
  print('Среднее значение мощности из графика больше среднего значения теоретического на ',P_razn )
else:
  P_razn=P_credn - P_mean
  print('Среднее значение мощности из графика больше среднего значения теоретического на ',P_razn )
# Out:
# Заголовок таблицы:
# Index(['2200'], dtype='object')
# Первые несколько строк:
#     2200
# 0   7700
# 1  12100
# 2  17600
# 3  23100
# 4  28600
# Последние несколько строк:
#         2200
# 60281 -23100
# 60282 -18700
# 60283 -14300
# 60284 -11000
# 60285  -5500
#
# Среднее значение= 2200   -182.1875
# dtype: float64 микроампер
#
# среднее значение мощности из графика =  2200    0.445426
# dtype: float64 Ватт
# Среднее значение мощности теоретическое =  2200    0.000003
# dtype: float64 Ватт
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-eabe3b188f53> in <cell line: 31>()
#      29
#      30 P_razn=P_mean-P_credn
# ---> 31 P_razn_bool=bool(P_razn)
#      32 if P_razn_bool:
#      33   print('Среднее значение мощности из графика больше среднего значения теоретического на ',P_razn )
#
# ...
